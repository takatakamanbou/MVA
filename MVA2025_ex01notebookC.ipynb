# %% [markdown]
# <a href="https://colab.research.google.com/github/takatakamanbou/MVA/blob/2025/MVA2025_ex01notebookC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MVA2025 ex01notebookC
#
# <img width=64 src="https://www-tlab.math.ryukoku.ac.jp/~takataka/course/MVA/MVA-logo.png"> https://www-tlab.math.ryukoku.ac.jp/wiki/?MVA/2024

# %% [markdown]
# <font color="#ff0000">
# 注意:
# 今回の notebook の中には，コードセルを実行すると問題の解答が表示されるようになっている箇所があります．
# </font>
# 読んで理解しながらひとつずつ実行していってください．

# %%
# 各種パッケージのインポートなど
import numpy as np
import matplotlib.pyplot as plt
import seaborn
seaborn.set_theme()
# 「解答」を示す際に文字列を復号するのに使う
import base64
# 復号した文字列を Markdown 形式で（数式は LaTeX でフォーマットして）表示
from IPython.display import display, Markdown

# %% [markdown]
# ---
# ## 演習課題
# ---

# %% [markdown]
# Colab Notebook に Python のコードを書いて， NumPy 配列の計算をしたり，Matplotlib でグラフを描いたりしてみましょう．

# %% [markdown]
# ---
# ### NumPy の初歩

# %% [markdown]
# #### 問題1
#
# 2つのベクトル
# $$ \pmb{a} = \left(1, \frac{3}{2}, 2, \frac{5}{2}\right),\quad \pmb{b} = (1, 3, -2, -7)$$
# に対するいくつかの演算を，Python + NumPy でやってみよう．

# %% [markdown]
# (1) 以下のセルに，$\pmb{a}$ と $\pmb{b}$ に相当する numpy.array を作り，その内容を print する（`print`関数を呼んで表示させる）コードを書きなさい．変数名は，それぞれ `a` と `b` とすること．

# %%
# このセルを実行すると，上の問題の解答が表示されます
Q = b'CmBgYAphID0gbnAuYXJyYXkoWzEsIDMvMiwgMiwgNS8yXSkKYiA9IG5wLmFycmF5KFsxLCAzLCAtMiwgLTddKQpwcmludChhKQpwcmludChiKQpgYGAK'
display(Markdown(base64.b64decode(Q).decode('utf-8')))

# %% [markdown]
# (2) 次の計算を行って得られたものをそれぞれ print するコードを書きなさい．
# - $\pmb{a} - \pmb{b}$
# - $4\pmb{a} + \pmb{b}$

# %%
# このセルを実行すると，上の問題の解答が表示されます
Q = b''
display(Markdown(base64.b64decode(Q).decode('utf-8')))

# %% [markdown]
# (3) 次の値を計算して結果を print するコードを書きなさい．
# - $\pmb{a}$ と $\pmb{b}$ の内積 $\pmb{a}\cdot\pmb{b}$
# - $\pmb{a}$ のノルム（大きさ）の2乗 $\Vert\pmb{a}\Vert^2$ （ヒント： 任意の実ベクトル $\pmb{x}$ に対して，$\Vert\pmb{x}\Vert^2 = \pmb{x}\cdot\pmb{x}$ です）

# %%
# このセルを実行すると，上の問題の解答が表示されます
Q = b'CmBgYApwcmludChhIEAgYikKcHJpbnQoYSBAIGEpCgphIOOBruODjuODq+ODoOOBrjLkuZfjga8gbnAuc3VtKGEqKjIpIOOBp+OCguaxguOCgeOCieOCjOOBvuOBmQpgYGAK'
display(Markdown(base64.b64decode(Q).decode('utf-8')))

# %% [markdown]
# (4) NumPy の関数 `np.sqrt` を使うと，スカラやベクトルの要素の平方根の値を求めることができます．使い方を調べて，次のものを計算して結果を print するコードを書きなさい．
# - $\Vert\pmb{a}\Vert$
# - ベクトル $\pmb{a}$ の各要素の平方根の値でできたベクトル

# %%
# このセルを実行すると，上の問題の解答が表示されます
Q = b'CmBgYApwcmludChucC5zcXJ0KGEgQCBhKSkKcHJpbnQobnAuc3FydChhKSkKYGBgCg=='
display(Markdown(base64.b64decode(Q).decode('utf-8')))

# %% [markdown]
# (5) $\pmb{a}, \pmb{b}$ それぞれの要素の値の和と平均を求めて結果を print するコードを書きなさい． 解説の notebook で示しているように NumPy の関数を使うこと．

# %%
# このセルを実行すると，上の問題の解答が表示されます
Q = b'CmBgYApwcmludChucC5zdW0oYSksIG5wLm1lYW4oYSkpCnByaW50KG5wLnN1bShiKSwgbnAubWVhbihiKSkKYGBgCg=='
display(Markdown(base64.b64decode(Q).decode('utf-8')))

# %% [markdown]
# #### 問題2
#
# 2次元配列

# %% [markdown]
# (1) 次のセルにコードを書いて，変数 `A` と `B` がそれぞれ次の行列 $A$ と $B$ を表す2次元配列となるようにしなさい．
#
# $$
# A = \begin{pmatrix}
# 0.1 & 0.2 \\
# 0.3 & 0.4\\
# \end{pmatrix}
# \quad
# B = \begin{pmatrix}
# 10 & -5 \\
# -10 & 0 \\
# 10 & -10 \\
# \end{pmatrix}
# $$

# %%
# このセルを実行すると，上の問題の解答が表示されます
Q = b'CmBgYApBID0gbnAuYXJyYXkoIFsgWzAuMSwgMC4yXSwgWzAuMywgMC40XSBdICkKcHJpbnQoQSkKcHJpbnQoKQpCID0gbnAuYXJyYXkoIFsgWzEwLCAtNV0sIFstMTAsIDBdLCBbMTAsIC0xMF0gXSApCnByaW50KEIpCmBgYAo='
display(Markdown(base64.b64decode(Q).decode('utf-8')))

# %% [markdown]
# (2) 次のセルに `A.shape` と `B.shape` を print するコードを書きなさい．

# %%
# このセルを実行すると，上の問題の解答が表示されます
Q = b'CmBgYApwcmludChBLnNoYXBlKQpwcmludChCLnNoYXBlKQpgYGAK'
display(Markdown(base64.b64decode(Q).decode('utf-8')))

# %% [markdown]
# (3) $A$ と $B$ それぞれの $(2, 1)$ 成分（2行目1列目の成分）を print するコードを書きなさい．ここでは，行や列の番号を，数学で一般的な表記ルール（1から数える）で表しています．それぞれ， $0.3$ と $-10$ になるはずです．

# %%
# このセルを実行すると，上の問題の解答が表示されます
Q = b'CmBgYApwcmludChBWzEsIDBdKQpwcmludChCWzEsIDBdKQpgYGAK'
display(Markdown(base64.b64decode(Q).decode('utf-8')))

# %% [markdown]
# (4) 次の積を求めて print するコードを書きなさい（これらの中には，積が求まらずエラーになるものもある）．
#
# $$
# AB \quad BA \quad AB^{\top}
# $$
#
# 一つのセルに複数行のコードを書いた場合，エラーが出た行以降が実行されません．
# 3つのコードセルに分けて書くとよいでしょう（一つのセルにまとめて書いて，エラーが出た行の先頭に `#` を付けてコメントにしておくのもあり），

# %%
# このセルを実行すると，上の問題の解答が表示されます
Q = b'CmBgYApwcmludChBIEAgQikgIyDjgqjjg6njg7zjgavjgarjgosKcHJpbnQoQiBAIEEpCnByaW50KEEgQCBCLlQpCmBgYAo='
display(Markdown(base64.b64decode(Q).decode('utf-8')))

# %% [markdown]
# ---
# ### Matplitlib の初歩

# %% [markdown]
# #### 問題3
#
# Python + NumPy + Matplotlib でグラフを描こう

# %% [markdown]
# (1) 次のセルを実行すると， 0 から 0.5 刻みで 2 までの数を並べた配列ができます．
# そのことを確認しなさい．

# %%
x = np.linspace(0, 2, 5)
print(x)

# %% [markdown]
# (2) 上記の `x` を用いて，次の配列を作るコードを書きなさい．
# - `y1`: `x` の各要素の2乗の値から成る配列
# - `y2`: `x` の各要素の平方根の値から成る配列

# %%
# このセルを実行すると，上の問題の解答が表示されます
Q = b'CmBgYAp5MSA9IHgqKjIKeTIgPSBucC5zcXJ0KHgpCgp5MSwgeTIg44KSIHByaW50IOOBmeOCi+OBqOasoeOBruOCiOOBhuOBq+OBquOCi+OBr+OBmgp5MTogWzAuICAgMC4yNSAxLiAgIDIuMjUgNC4gIF0KeTI6IFswLiAgICAgICAgIDAuNzA3MTA2NzggMS4gICAgICAgICAxLjIyNDc0NDg3IDEuNDE0MjEzNTZdCmBgYAo='
display(Markdown(base64.b64decode(Q).decode('utf-8')))

# %% [markdown]
# (3) `x` の各要素をX座標，`y1` の各要素をY座標にとった折れ線グラフを描きなさい．
# ただし，X軸の範囲は $[0, 2]$，Y軸の範囲は $[0,4]$ とすること．

# %%
# このセルを実行すると，上の問題の解答が表示されます
Q = b'...'
display(Markdown(base64.b64decode(Q).decode('utf-8')))

# %% [markdown]
# ［補足］ グラフの縦横の比率を揃えたい（X軸の値0から1までの長さとY軸の値0から1までの長さを等しくしたい）場合は，
# ```python
# ax.set_aspect('equal')
# ```
# を入れれば ok です．

# %% [markdown]
# (4) 上のセルを修正して，`x` に対する `y2` のグラフも重ねて描くようにしなさい．

# %% [markdown]
# (5) `np.linspace` 関数の使い方を調べて，(1) のコードセルを実行すると`x` が「0から 0.02 刻みで 2 までの数を並べた」配列となるようにセルを修正しなさい．
# その後，(2), (3), (4) のセルを順に実行して，より滑らかなグラフが得られることを確認しなさい．

# %%
# このセルを実行すると，上の問題の解答が表示されます
Q = b''
display(Markdown(base64.b64decode(Q).decode('utf-8')))

# %% [markdown]
# #### 問題4

# %% [markdown]
# 4つの配列を次のように定めるとき，次の問に答えなさい．

# %%
eyeX = np.array([195, 195, 135, 135, 155, 155,  95,  95, 120, 120, 170, 170, 195])
eyeY = np.array([170, 245, 245, 225, 225, 245, 245, 170, 170, 195, 195, 170, 170])
mouthX = np.array([345, 320, 320,  70,  70, 345, 345])
mouthY = np.array([45, 45, 70, 70, 95, 95, 45])

# %% [markdown]
# (1) `eyeX` を X 座標の値，`eyeY` を Y 座標の値として，Matplotlib を使って散布図を描きなさい．ただし，X 軸の範囲は $[0, 400]$，Y 軸の範囲は $[0, 300]$ とすること．

# %% [markdown]
# (2) 上記のコードセルを修正して，次のものも追加で重ねて描くようにしなさい．
# - 「`eyeX` の各要素の値に 150 を加えたもの」を X 座標の値，`eyeY` を Y 座標の値とした散布図
# - `mouthX` を X 座標の値，`mouthY` を Y 座標の値とした散布図

# %% [markdown]
# (3) 上記のコードセルを修正して，散布図の代わりに折れ線グラフを描くようにしなさい．
