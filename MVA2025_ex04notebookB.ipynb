# %% [markdown]
# <a href="https://colab.research.google.com/github/takatakamanbou/MVA/blob/2025/MVA2025_ex04notebookB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MVA2025 ex04notebookB
#
# <img width=64 src="https://www-tlab.math.ryukoku.ac.jp/~takataka/course/MVA/MVA-logo.png"> https://www-tlab.math.ryukoku.ac.jp/wiki/?MVA

# %% [markdown]
# <font color="#ff0000">
# 注意:
# 今回の notebook の中には，コードセルを実行すると問題の解答が表示されるようになっている箇所があります．
# </font>
# 読んで理解しながらひとつずつ実行していってください．

# %% [markdown]
# ---
# ## 演習課題 アパート・マンションの家賃を説明する重回帰分析
# ---

# %% [markdown]
# ---
# ### 準備

# %% [markdown]
# #### import

# %%
# 必要なパッケージのインポート
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn
seaborn.set_theme()
import statsmodels.api as sm
# 解答表示のため
import base64
from IPython.display import display, Markdown

# %% [markdown]
# #### データの入手
#
# 次の二つのコードセルを実行すると，とあるCSVファイルを読み込んで 2 つの NumPy array `X` と `Y` を作ります．
# 実行して結果を観察しよう．
#
# これは，ある駅周辺の様々なアパート・マンションのデータです．'x1', 'x2', 'x3' 列にはそれらの特徴を表す数値が入っており（それぞれが何を表すのかはあえて伏せています），'y'列には月額の家賃（単位は千円）を表す数値が入っています．

# %%
# データを読み込む
df = pd.read_csv('https://www-tlab.math.ryukoku.ac.jp/~takataka/course/MVA/ex04rent.csv')
df['y'] /= 1000
df

# %% [markdown]
# 次のコードセルを実行すると，`X` に説明変数の値が，`Y` に被説明変数の値が格納されます．

# %%
# x1, x2, x3 列を集めて X とする
X = df.loc[:, ['x1', 'x2', 'x3']].to_numpy()
# y 列を Y とする
Y = df['y'].to_numpy()
print(X.shape, Y.shape)

# %% [markdown]
# ---
# ### 問題1 そのまま重回帰分析する

# %% [markdown]
# (1) 次のセルに，'x1', 'x2', 'x3' を説明変数，'y' を被説明変数として重回帰分析を行うコードを書きなさい．ただし，notebookA を参考にして，statsmodel を使い，結果（summary）を表示させること．

# %%
# このセルを実行すると，上の問題の解答が表示されます
Q = b'Cuino+etlOS+i++8mgpgYGAKWDEgPSBzbS5hZGRfY29uc3RhbnQoWCkKbW9kZWwgPSBzbS5PTFMoWSwgWDEpCnJ2ID0gbW9kZWwuZml0KCkKcHJpbnQocnYuc3VtbWFyeSgpKQpgYGAK'
display(Markdown(base64.b64decode(Q).decode('utf-8')))

# %% [markdown]
# (2) 説明変数 'x1', 'x2', 'x3' を $x_1, x_2, x_3$ と表し，被説明変数 'y' を $y$ と表す．これらの間に
#
# $$
# y = w_0 + w_1x_1 + w_2x_2 + w_3x_3 + (誤差項)
# $$
#
# という関係が成り立つとするとき，$w_0, w_1, w_2, w_3$ はそれぞれいくつと推定されたか答えなさい．また，'x1', 'x2', 'x3' のうち，その変数の値が大きくなると被説明変数の値も大きくなると予測されるものはどれか答えなさい．

# %% [markdown]
# 解答例は省略．

# %% [markdown]
# (3) 上記の summary を見ると，3つの説明変数のうち，被説明変数に影響していると言えそうなものは実は一つしかないことが分かる．それはどれか．

# %%
# このセルを実行すると，上の問題の解答が表示されます
Q = b'...'
display(Markdown(base64.b64decode(Q).decode('utf-8')))

# %% [markdown]
# ---
# ### 問題2 モデルを変えて自由度調整済み決定係数をみる

# %% [markdown]
# 問題1で用いた 'x1', 'x2', 'x3' を全て説明変数とするモデルは，実は妥当ではないかもしれません．'x1', 'x2', 'x3' のうちの一部だけを説明変数とするモデルもいくつか作ってみて，どのモデルがよいか検討してみましょう．
#
#
# - statsmodel を使い，説明変数1つだけ，2つ，3つのすべてのモデルを考えて，それぞれの回帰分析を行いなさい
# - notebookA を参考に，statsmodel を使ってそれぞれのモデルの結果（summary）を表示させなさい．一つのセルを書き換えて実行するのではなく，すべてのモデルの分析記録が残るように，別々のセルを作るようにしなさい．
# - 分析結果のうち，自由度調整済み決定係数の値について，↓の表が書かれたセル（ほげとかふがとか書いてあるもの）にメモしておきなさい．
# セルをダブルクリックしたら書き方が分かると思います．
# - 分析結果を見て，自由度調整済み決定係数の値のみを基準に最も適切なモデルを選ぶとしたらどれかを考えなさい．

# %% [markdown]
# このテキストセルに，問題2の結果をまとめることにしましょう．
# このセルをダブルクリックして，↓の表の「問題1で得られる値をここに書く」の所に，問題1の実験で得られた自由度調整済み決定係数の値を書いておきましょう．
#
# | 説明変数 | 自由度調整済み決定係数 |
# |--|--|
# | x1, x2, x3 | 問題1で得られる値をここに書く |
# | x1, x2 | ほげ |
# | ふが | へな |

# %% [markdown]
# (1) 次のセルを修正して，`XX` と `Y` を用いて重回帰分析を行い，結果を表示するコードを書きなさい．得られた自由度調整済み決定係数の値を上の表に記入しなさい．

# %%
XX = df.loc[:, ['x1', 'x2']].to_numpy() # 元データから `x1` と `x2` のみを取り出す
print(XX[:5, :]) # 最初の5行を表示
# 以下に続きを書きましょう

# %% [markdown]
# (2) (1) で得たものとは別の 'x1', 'x2', 'x3' から2つを用いるモデル，および，変数を1つだけ用いるモデルについても (1) と同様の実験を行い，得られた自由度調整済み決定係数の値を上の表に書き込みなさい．

# %% [markdown]
# (3) 得られた自由度調整済み決定係数の値に基づくと，どの変数を説明変数とするモデルが最も妥当と言えるか答えなさい．

# %%
# このセルを実行すると，上の問題の解答が表示されます
Q = b'...'
display(Markdown(base64.b64decode(Q).decode('utf-8')))

# %% [markdown]
# ---
# ### 問題3 多重共線性

# %% [markdown]
# 問題1と問題2の結果から，このデータでは多重共線性の存在が疑われることがわかります（問題1の summary を見ると警告が出ていたりする）．
# 相関係数や散布図でそのことを確認してみましょう．

# %% [markdown]
# (1) 次のセルを実行すると，各変数の間の相関係数の値を表示します．$i$ 行 $j$ 列の値は，$i$ 番目の変数と $j$ 番目の変数との間の相関係数です．結果を確認し，相関係数の値が大きい変数ペアを探しましょう．
#
# cf. [np.corrcoef](https://numpy.org/doc/stable/reference/generated/numpy.corrcoef.html)

# %%
XX = df.loc[:, ['x1', 'x2', 'x3']].to_numpy()
print(np.corrcoef(XX.T))

# %% [markdown]
# (2) 'x1' と 'x2' および 'x1' と 'x3' の散布図を描きましょう．縦軸横軸の範囲は全て [0, 80] でok．

# %%
# このセルを実行すると，上の問題の解答が表示されます
Q = b'...'
display(Markdown(base64.b64decode(Q).decode('utf-8')))

# %% [markdown]
# (3) (1), (2) の結果を考察し，x1, x2, x3 のうち多重共線性があるとみられる変数ペアはどれか答えなさい．

# %%
# このセルを実行すると，上の問題の解答が表示されます
Q = b'...'
display(Markdown(base64.b64decode(Q).decode('utf-8')))
