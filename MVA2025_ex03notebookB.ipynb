# %% [markdown]
# <a href="https://colab.research.google.com/github/takatakamanbou/MVA/blob/2025/MVA2025_ex03notebookB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MVA2025 ex03notebookB
#
# <img width=64 src="https://www-tlab.math.ryukoku.ac.jp/~takataka/course/MVA/MVA-logo.png"> https://www-tlab.math.ryukoku.ac.jp/wiki/?MVA

# %% [markdown]
# <font color="#ff0000">
# 注意:
# 今回の notebook の中には，コードセルを実行すると問題の解答が表示されるようになっている箇所があります．
# </font>
# 読んで理解しながらひとつずつ実行していってください．

# %%
# いろいろインポート
import numpy as np
import pandas as pd
# 解答表示のため
import base64
from IPython.display import display, Markdown

# %% [markdown]
# ---
# ## Python + NumPy で重回帰分析
# ---

# %% [markdown]
# ---
# ### 問題1
#
# 次のセルを実行すると，notebookA で使っていたのと同じデータを読み込んで変数 `X` と `Y` に代入してくれます（**変数のならび順の違いに注意**）．
# 実行して結果を観察し，次のことをやりなさい：
# - `X.shape` と `Y.shape` の値を print する行を追加して，それぞれの値をメモしておきなさい．
# - notebookA の解説で使っている記号を使うと，このデータの場合の $N$ と $D$ はそれぞれいくつか考え，メモしておきなさい

# %%
# このセルの内容は変更してはならない
# データの読み込み
df = pd.read_csv('https://github.com/ghmagazine/python_stat_sample/raw/master/data/ch12_scores_reg.csv')
X = df.loc[:, ['睡眠時間', '小テスト']].to_numpy()
print(X)
print()
Y = df['期末テスト'].to_numpy()
print(Y)

# %%
# このセルを実行すると，上の問題の解答が表示されます
Q = b'Cu+8iOS4gOOBpOebru+8iSDpganlvZPjgarloLTmiYDjgavmrKHjgpLmjL/lhaUKYGBgCiAgIHByaW50KCJYLnNoYXBlID0iLCBYLnNoYXBlLCAiIFkuc2hhcGUgPSIsIFkuc2hhcGUpCmBgYAoK77yI5LqM44Gk55uu44Gu6Kej562U44Gv55yB55Wl77yJCg=='
display(Markdown(base64.b64decode(Q).decode('utf-8')))

# %% [markdown]
# ---
# ### 問題2
#
# 問題1で読み込んだデータに対して，最小二乗法で平面を当てはめてみよう．
# 次のことをやりなさい．
#
# 1. 以下のセルを実行すると回帰係数（平面を表す式のパラメータ）の値が print されるように，コメントにしたがってセルの中身を修正しなさい．
# 1. 得られた回帰係数が正しいことを，notebookA の値と比較して確認しなさい．
# 変数の並び順に注意．

# %%
# X に 1 の列を付け足した配列 X1 をつくる
X1 = np.column_stack([np.ones(len(X)), X])
# 修正するのは次の行の lstsq の引数だけ
rv = np.linalg.lstsq(ほげ)
w = rv[0]
print(f"w_0 = {w[0]:.3f},  w_1 = {w[1]:.3f},  w_2 = {w[2]:.3f}")

# %%
# このセルを実行すると，上の問題の解答が表示されます
Q = b'CmBgYApydiA9IG5wLmxpbmFsZy5sc3RzcShYMSwgWSkKYGBgCg=='
display(Markdown(base64.b64decode(Q).decode('utf-8')))

# %% [markdown]
# ---
# ### 問題3
#
# 上記のデータから得られた回帰係数 $(w_0, w_1, w_2)$ を用いて，予測値を計算してみよう．

# %% [markdown]
# (1) 次のセルが何をやっているかを理解しなさい．ヒント: `XX1`, `w`, `YY` の shape を調べて，`YY = XX1 @ w` がどんな計算をしているのか考えましょう．

# %%
# このセルの内容は変更してはならない
XX  = np.array([[5, 8], [8, 5]])
XX1 = np.column_stack([np.ones(len(XX)), XX])
YY = XX1 @ w
print(YY)

# %%
# このセルを実行すると，上の問題の解答が表示されます
Q = b'CuaxguOCgeOBn+WbnuW4sOS/guaVsOOCkueUqOOBhO+8jCjnnaHnnKDmmYLplpMsIOWwj+ODhuOCueODiCkg44GMICQoNSwgOCkkIOOBqCAkKDgsIDUpJCDjga7jgbLjgajjga7mnJ/mnKvjg4bjgrnjg4jjga7kuojmuKzlgKTjgpLoqIjnrpfjgZfjgabjgYTjgovvvI4K'
display(Markdown(base64.b64decode(Q).decode('utf-8')))

# %% [markdown]
# (2) (1) をふまえて，次のセルに，与えられたデータ（配列`X`に入っていたデータ）に対する予測値を求めてそれらを配列 `Yp` に代入し，その内容を print するコードを書きなさい．

# %%
# このセルを実行すると，上の問題の解答が表示されます
Q = b''
display(Markdown(base64.b64decode(Q).decode('utf-8')))

# %% [markdown]
# ### 問題4
#
# 決定係数を求めてみよう．

# %% [markdown]
# (1) 問題3までの結果を使って，
# $$
# \sum_{n=1}^{N}(y_n - \widehat{y}_n)^2
# $$
# の値を求めて適当な名前の変数に代入するコードを書きなさい．
# この式の記号の意味は notebookA で説明している通りである．

# %%
# このセルを実行すると，上の問題の解答が表示されます
Q = b'CmBgYAp2ID0gWSAtIFlwCnNxZSA9IHYgQCB2CnByaW50KHNxZSkKCu+8iOWIpeino++8iQpzcWUgPSBucC5zdW0oKFkgLSBZcCkqKjIpCnByaW50KHNxZSkKYGBgCg=='
display(Markdown(base64.b64decode(Q).decode('utf-8')))

# %% [markdown]
# (2) (1)と同様に，
# $$
# \sum_{n=1}^{N}(y_n - \bar{y})^2
# $$
# の値を求めて適当な名前の変数に代入するコードを書きなさい．

# %% [markdown]
# 解答例は省略

# %% [markdown]
# (3) (1), (2) の結果を利用して決定係数の値を計算して print するコードを書きなさい．
# 得られた決定係数の値をメモしておきなさい（小数第4位を四捨五入して第3位までにした値でよい）．

# %%
# このセルを実行すると，上の問題の解答が表示されます
Q = b'CmBgYArjgrPjg7zjg4njga/nnIHnlaXvvI7lvpfjgonjgozjgovmsbrlrprkv4LmlbDjga7lgKTjga/vvIwwLjc1NiDjgavjgarjgovjga/jgZrjgafjgZnvvI4KYGBgCg=='
display(Markdown(base64.b64decode(Q).decode('utf-8')))
